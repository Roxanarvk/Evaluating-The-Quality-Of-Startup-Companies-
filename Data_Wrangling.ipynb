# %%
import pandas as pd
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB # Gaussian Naive Bays
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier #stochastic gradient descent
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Importing Data

# %%
pd.read_csv('crunchbase_monthly_export.csv', engine='python')
# Out:
#                                 name                           homepage_url  \
# 0                           #waywire                 http://www.waywire.com
# 1                 &TV Communications                  http://enjoyandtv.com
# 2                  'Rock' Your Paper           http://www.rockyourpaper.org
# 3                  (In)Touch Network          http://www.InTouchNetwork.com
# 4                             #NAME?                       http://plusn.com
# 5                 -R- Ranch and Mine                                    NaN
# 6                      .Club Domains                       http://nic.club/
# 7                      .Fox Networks                  http://www.dotfox.com
# 8                            0-6.com                     http://www.0-6.com
# 9                   004 Technologies      http://004gmbh.de/en/004-interact
# 10                01Games Technology                 http://www.01games.hk/
# ...

# %%
with open('crunchbase_monthly_export.csv', encoding="latin-1") as datafile:
    new_df= pd.read_csv(datafile)

# %%
new_df.head()
# Out:
#                  name                   homepage_url        market   \
# 0            #waywire         http://www.waywire.com          News
# 1  &TV Communications          http://enjoyandtv.com         Games
# 2   'Rock' Your Paper   http://www.rockyourpaper.org    Publishing
# 3   (In)Touch Network  http://www.InTouchNetwork.com   Electronics
# 4              #NAME?               http://plusn.com      Software
#
#    funding_total_usd      status country_code state_code         region  \
# 0           1,750,000   acquired          USA         NY  New York City
# 1           4,000,000  operating          USA         CA    Los Angeles
# 2              40,000  operating          EST        NaN        Tallinn
# 3           1,500,000  operating          GBR        NaN         London
# 4           1,200,000  operating          USA         NY  New York City
#
#           city  funding_rounds founded_at founded_month founded_quarter  \
# ...

# %%
new_df.info
# Out:
# <bound method DataFrame.info of                                 name                           homepage_url  \
# 0                           #waywire                 http://www.waywire.com
# 1                 &TV Communications                  http://enjoyandtv.com
# 2                  'Rock' Your Paper           http://www.rockyourpaper.org
# 3                  (In)Touch Network          http://www.InTouchNetwork.com
# 4                             #NAME?                       http://plusn.com
# 5                 -R- Ranch and Mine                                    NaN
# 6                      .Club Domains                       http://nic.club/
# 7                      .Fox Networks                  http://www.dotfox.com
# 8                            0-6.com                     http://www.0-6.com
# 9                   004 Technologies      http://004gmbh.de/en/004-interact
# 10                01Games Technology                 http://www.01games.hk/
# ...

# %%
new_df.shape
# Out:
# (47758, 16)

# %%
# Descriptive statistics for each column
new_df.describe()
# Out:
#        funding_rounds  founded_year
# count    47758.000000  37255.000000
# mean         1.688576   2007.247135
# std          1.282093      7.589313
# min          1.000000   1900.000000
# 25%          1.000000   2005.000000
# 50%          1.000000   2009.000000
# 75%          2.000000   2012.000000
# max         17.000000   2015.000000

# %% [markdown]
# # Data Wrangling

# %%
# Drop the frequencies column and two other columns that will not be used in the model.
features = new_df.drop (['homepage_url','founded_month'], axis= 1)

# %%
features.head()
# Out:
#                  name        market   funding_total_usd      status  \
# 0            #waywire          News            1,750,000   acquired
# 1  &TV Communications         Games            4,000,000  operating
# 2   'Rock' Your Paper    Publishing               40,000  operating
# 3   (In)Touch Network   Electronics            1,500,000  operating
# 4              #NAME?      Software            1,200,000  operating
#
#   country_code state_code         region         city  funding_rounds  \
# 0          USA         NY  New York City     New York               1
# 1          USA         CA    Los Angeles  Los Angeles               2
# 2          EST        NaN        Tallinn      Tallinn               1
# 3          GBR        NaN         London       London               1
# 4          USA         NY  New York City     New York               2
#
#   founded_at founded_quarter  founded_year first_funding_at last_funding_at
# ...

# %%
features_clean = features.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
print (features_clean)
# Out:
#                      name                    market   funding_total_usd   \
# 0                #waywire                      News            1,750,000
# 4                  #NAME?                  Software            1,200,000
# 5      -R- Ranch and Mine                     Games               10,000
# 9        004 Technologies                  Software                 -
# 11                 0xdata                 Analytics           10,600,000
# 14          1-800-DENTIST       Health and Wellness                 -
# 15          1-800-DOCTORS       Health and Wellness            1,750,000
# 16       1.618 Technology               Real Estate                 -
# 17            10-20 Media                E-Commerce            2,050,000
# 18             1000 Corks                    Search               40,000
# 21           1000memories               Curated Web            2,535,000
# 22        1000museums.com               Curated Web            4,962,651
# ...

# %%
#Correlation between features and labels
features.corr()
# Out:
#                 funding_rounds  founded_year
# funding_rounds         1.00000      -0.05837
# founded_year          -0.05837       1.00000
